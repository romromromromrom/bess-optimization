# %% [markdown]
# # Démonstration BESS Optimization
# Ce notebook reste volontairement mince : toute la logique réutilisable vit dans `src/`.

# %%
from bess_optimization.config import AnalysisConfig
from bess_optimization.pipelines.run_analysis import run_analysis

config = AnalysisConfig.from_yaml('../configs/example.yaml')
result = run_analysis(config, export=False)
result.risk

# %%
from bess_optimization.visualization.charts import pnl_comparison_chart

pnl_comparison_chart(result.hedge.unhedged_pnl_eur, result.hedge.hedged_pnl_eur)
